# %% [markdown]
# <a href="https://colab.research.google.com/github/Surabatthinimounika9999/restaurant_sales_forecasting/blob/master/data_analysis_telecust_(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-48546430-f331-42d4-8c5b-28acde45cf42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48546430-f331-42d4-8c5b-28acde45cf42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
path = 'telecust1.csv'
df = pd.read_csv(path)
df.tail(5)
# Out:
#      region  age  marital  address  income ed  retire  gender  reside  custcat
# 995       3   39        0        0      27  3       0       1       3        1
# 996       1   34        0        2      22  5       0       1       1        1
# 997       3   59        0       40     944  5       0       1       1        4
# 998       3   49        0       18      87  2       0       1       1        3
# 999       3   36        1        7      39  3       0       1       3        2

# %%
import numpy as np

# %%
df.head(10)
# Out:
#    region  age  marital  address  income   ed  retire  gender  reside  custcat
# 0       2   35        1        9      64    4       0       0       2        1
# 1       3   23        1        7     136  NaN       0       0       6        4
# 2       3   52        1       24     116    1       0       1       2        3
# 3       2   34        0       12      33    2       0       1       1        1
# 4       2   30        1        9      30    1       0       0       4        3
# 5       2   39        0       17      78    2       0       1       1        3
# 6       3   23        1        2      19    2       0       1       5        2
# 7       2   35        0        5      76    2       0       0       3        4
# 8       3   59        1        7     166    ?       0       0       5        3
# 9       1   41        1       21      72    1       0       0       3        2

# %%
df['age']
# Out:
# 0      35
# 1      23
# 2      52
# 3      34
# 4      30
#        ..
# 995    39
# 996    34
# 997    59
# 998    49
# 999    36
# Name: age, Length: 1000, dtype: int64

# %%
df[['address', 'ed']]
# Out:
#      address   ed
# 0          9    4
# 1          7  NaN
# 2         24    1
# 3         12    2
# 4          9    1
# ..       ...  ...
# 995        0    3
# 996        2    5
# 997       40    5
# 998       18    2
# 999        7    3
#
# [1000 rows x 2 columns]

# %%
df.describe()
# Out:
#           region          age      marital      address       income  \
# count  1000.0000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.0220    41.645000     0.495000    11.551000    77.535000
# std       0.8162    12.581545     0.500225    10.086681   107.044165
# min       1.0000    18.000000     0.000000     0.000000     9.000000
# 25%       1.0000    32.000000     0.000000     3.000000    29.000000
# 50%       2.0000    40.000000     0.000000     9.000000    47.000000
# 75%       3.0000    51.000000     1.000000    18.000000    83.000000
# max       3.0000    77.000000     1.000000    55.000000  1668.000000
#
#             retire       gender       reside      custcat
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.047000     0.517000     2.331000     2.487000
# std       0.211745     0.499961     1.435793     1.120306
# min       0.000000     0.000000     1.000000     1.000000
# ...

# %%
df.isnull().sum()
# Out:
# region     0
# age        0
# marital    0
# address    0
# income     0
# ed         1
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df['ed'].value_counts()
# Out:
# ed
# 2    287
# 4    233
# 3    209
# 1    204
# 5     65
# ?      1
# Name: count, dtype: int64

# %%
df.replace("?", np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# region     0
# age        0
# marital    0
# address    0
# income     0
# ed         2
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df.dropna(subset=["ed"], axis=0, inplace = True)

# %%
df.isnull().sum()
# Out:
# region     0
# age        0
# marital    0
# address    0
# income     0
# ed         0
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df['age'].max()
# Out:
# 77

# %%
df.corr()
# Out:
# <ipython-input-15-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            region       age   marital   address    income    retire    gender  \
# region   1.000000  0.014484 -0.083269  0.011423  0.022158  0.006138  0.053215
# age      0.014484  1.000000 -0.017808  0.660881  0.325990  0.430235 -0.007843
# marital -0.083269 -0.017808  1.000000 -0.011151 -0.045443 -0.077742  0.010461
# address  0.011423  0.660881 -0.011151  1.000000  0.227561  0.292376  0.007437
# income   0.022158  0.325990 -0.045443  0.227561  1.000000 -0.083391  0.040193
# retire   0.006138  0.430235 -0.077742  0.292376 -0.083391  1.000000  0.053506
# gender   0.053215 -0.007843  0.010461  0.007437  0.040193  0.053506  1.000000
# reside  -0.070921 -0.256510  0.625304 -0.200696 -0.101089 -0.139846  0.021264
# ...

# %%
df.dtypes
# Out:
# region      int64
# age         int64
# marital     int64
# address     int64
# income      int64
# ed         object
# retire      int64
# gender      int64
# reside      int64
# custcat     int64
# dtype: object

# %%
avg = df['ed'].astype("float").mean()

# %%
df.replace(np.nan, avg, inplace=True)

# %%
df.isnull().sum()
# Out:
# region     0
# age        0
# marital    0
# address    0
# income     0
# ed         0
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df.dtypes
# Out:
# region      int64
# age         int64
# marital     int64
# address     int64
# income      int64
# ed         object
# retire      int64
# gender      int64
# reside      int64
# custcat     int64
# dtype: object

# %%
df.head()
# Out:
#    region  age  marital  address  income ed  retire  gender  reside  custcat
# 0       2   35        1        9      64  4       0       0       2        1
# 2       3   52        1       24     116  1       0       1       2        3
# 3       2   34        0       12      33  2       0       1       1        1
# 4       2   30        1        9      30  1       0       0       4        3
# 5       2   39        0       17      78  2       0       1       1        3
